# %% [markdown]
# <a href="https://colab.research.google.com/github/Fa2378/Python-/blob/main/Capstone_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
maternalpd = pd.read_csv('/content/drive/MyDrive/Data folder/Fertility_rate.csv')
maternalpd.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Unmet need for contraception (% of married wom...        SP.UWT.TFRT   NaN
# 1  Completeness of death registration with cause-...     SP.REG.DTHS.ZS   NaN
# 2             Completeness of birth registration (%)     SP.REG.BRTH.ZS   NaN
# 3      Completeness of birth registration, urban (%)  SP.REG.BRTH.UR.ZS   NaN
# 4      Completeness of birth registration, rural (%)  SP.REG.BRTH.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2014  2015  2016  2017  2018  2019  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
maternalpd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65532 entries, 0 to 65531
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    65532 non-null  object
#  1   Country Code    65532 non-null  object
#  2   Indicator Name  65532 non-null  object
#  3   Indicator Code  65532 non-null  object
#  4   1960            20157 non-null  float64
#  5   1961            19957 non-null  float64
#  6   1962            19966 non-null  float64
#  7   1963            19997 non-null  float64
#  8   1964            20043 non-null  float64
#  9   1965            20402 non-null  float64
#  10  1966            20116 non-null  float64
#  11  1967            20139 non-null  float64
#  12  1968            20197 non-null  float64
#  13  1969            20280 non-null  float64
#  14  1970            20850 non-null  float64
#  15  1971            20396 non-null  float64
#  16  1972            20437 non-null  float64
# ...

# %%
maternalpd['Country Name'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %%
# I used the loop function to find all the names that is in the Indicator name column
for index, row in maternalpd.iterrows():
  print(row['Indicator Name'])
# Out:
# Streaming output truncated to the last 5000 lines.
# Mortality rate, infant, male (per 1,000 live births)
# Mortality rate, infant (per 1,000 live births)
# Mortality rate, infant, female (per 1,000 live births)
# Contraceptive prevalence, any method (% of married women ages 15-49)
# Contraceptive prevalence, any modern method (% of married women ages 15-49)
# Death rate, crude (per 1,000 people)
# Birth rate, crude (per 1,000 people)
# Mortality rate, adult, male (per 1,000 male adults)
# Mortality rate, adult, female (per 1,000 female adults)
# Adolescent fertility rate (births per 1,000 women ages 15-19)
# Vitamin A supplementation coverage rate (% of children ages 6-59 months)
# Prevalence of severe food insecurity in the population (%)
# Consumption of iodized salt (% of households)
# Prevalence of moderate or severe food insecurity in the population (%)
# Prevalence of undernourishment (% of population)
# International migrant stock (% of population)
# ...

# %%
sorted_maternal_mor = maternal_mor[['Country Name', 'Indicator Name', '2020']]
sorted_maternal_mor = sorted_maternal_mor.sort_values(by='2020', ascending=False)
sorted_maternal_mor.head(25)
# Out:
#                                      Country Name  \
# 55028                                 South Sudan
# 58330                                        Chad
# 44360                                     Nigeria
# 8800                     Central African Republic
# 926                    Africa Western and Central
# 22262                               Guinea-Bissau
# 33438                                     Liberia
# 54266                                     Somalia
# 672                                   Afghanistan
# 26834                                   IDA blend
# 35978                                     Lesotho
# 48678                    Pre-demographic dividend
# 21754                                      Guinea
# 11086                            Congo, Dem. Rep.
# 18960    Fragile and conflict affected situations
# 55282                          Sub-Saharan Africa
# 30898                                       Kenya
# 4736                                        Benin
# ...

# %%
african_countries = maternalpd[(maternalpd['Country Name'].isin(['South Sudan','Chad','Nigeria'])) &
                             (maternalpd['Indicator Name'].isin(['Population ages 15-64, female',
                                                            'Survival to age 65, female (% of cohort)',
                                                            'Fertility rate, total (births per woman)',
                                                            'Mortality rate, adult, female (per 1,000 female adults)',
                                                             'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
                                                            'Lifetime risk of maternal death (%)']))]\
                                                            [['Country Name', 'Indicator Name', '2020']]
african_countries.head(20)
# Out:
#       Country Name                                     Indicator Name  \
# 44250      Nigeria                      Population ages 15-64, female
# 44271      Nigeria           Survival to age 65, female (% of cohort)
# 44272      Nigeria           Fertility rate, total (births per woman)
# 44284      Nigeria  Mortality rate, adult, female (per 1,000 femal...
# 44360      Nigeria  Maternal mortality ratio (modeled estimate, pe...
# 44387      Nigeria                Lifetime risk of maternal death (%)
# 54918  South Sudan                      Population ages 15-64, female
# 54939  South Sudan           Survival to age 65, female (% of cohort)
# 54940  South Sudan           Fertility rate, total (births per woman)
# 54952  South Sudan  Mortality rate, adult, female (per 1,000 femal...
# 55028  South Sudan  Maternal mortality ratio (modeled estimate, pe...
# 55055  South Sudan                Lifetime risk of maternal death (%)
# ...

# %%
sns.barplot(data=african_countries[african_countries['Indicator Name'] == 'Population ages 15-64, female'],
            x = 'Country Name', y='2020',hue='Country Name')
plt.title('Population ages 15-64, female')
plt.show()

# %%
sns.barplot(data=african_countries[african_countries['Indicator Name'] == 'Survival to age 65, female (% of cohort)'],
            x = 'Country Name', y='2020',hue='Country Name')
plt.title('Survival to age 65, female (% of cohort)')
plt.show()

# %%
sns.barplot(data=african_countries[african_countries['Indicator Name'] == 'Mortality rate, adult, female (per 1,000 female adults)'],
            x = 'Country Name', y='2020',hue='Country Name')
plt.title('Mortality rate, adult, female (per 1,000 female adults)')
plt.show()

# %%
sns.barplot(data=african_countries[african_countries['Indicator Name'] == 'Lifetime risk of maternal death (%)'],
            x = '2020', y='Country Name',hue='2020')
plt.title('Lifetime risk of maternal death (%)')
plt.show()

# %%
african2_countries = maternalpd[(maternalpd['Country Name'].isin(['South Sudan','Chad','Nigeria'])) &
                             (maternalpd['Indicator Name'].isin(['Population ages 15-64, female',
                                                            'Survival to age 65, female (% of cohort)',
                                                            'Fertility rate, total (births per woman)',
                                                            'Mortality rate, adult, female (per 1,000 female adults)',
                                                             'Maternal mortality ratio (modeled estimate, per 100,000 live births)', 'Population, female',
                                                            'Lifetime risk of maternal death (%)']))]\
                                                            [['Country Name', 'Indicator Name', '2020']]
african_countries.head(50)
# Out:
#       Country Name                                     Indicator Name  \
# 44250      Nigeria                      Population ages 15-64, female
# 44271      Nigeria           Survival to age 65, female (% of cohort)
# 44272      Nigeria           Fertility rate, total (births per woman)
# 44284      Nigeria  Mortality rate, adult, female (per 1,000 femal...
# 44360      Nigeria  Maternal mortality ratio (modeled estimate, pe...
# 44387      Nigeria                Lifetime risk of maternal death (%)
# 54918  South Sudan                      Population ages 15-64, female
# 54939  South Sudan           Survival to age 65, female (% of cohort)
# 54940  South Sudan           Fertility rate, total (births per woman)
# 54952  South Sudan  Mortality rate, adult, female (per 1,000 femal...
# 55028  South Sudan  Maternal mortality ratio (modeled estimate, pe...
# 55055  South Sudan                Lifetime risk of maternal death (%)
# ...

# %%
sns.barplot(data=african_countries[african_countries['Indicator Name'] == 'Population, female'],
            x = 'Country Name', y='2020',hue='Country Name')
plt.title('Fertility rate, total (births per woman)')
plt.show()

# %%
sns.barplot(data=african_countries[african_countries['Indicator Name'] == 'Fertility rate, total (births per woman)'],
            x = 'Country Name', y='2020',hue='Country Name')
plt.title('Fertility rate, total (births per woman)')
plt.show()

# %%
plt.style.use ('fivethirtyeight')
slices= [5.3,4.5,6.3]
labels = ['Nigeria', 'South Sudan', 'Chad']
colors = ['#dda0dd', '#a0ddd2', '#b4a0dd']
explode = [0,0,0.1]


 #['#008fd5', '#e5ae37', '#6d984f']
plt.pie(slices, labels=labels, explode=explode, shadow=True, startangle=90, autopct= '%1.1f%%',colors=colors, wedgeprops={'edgecolor':'black'})

plt.title('Fertility rate, total (births per woman)')
plt.tight_layout()
plt.show()

# %%
sns.barplot(data=african_countries[african_countries['Indicator Name'] == 'Maternal mortality ratio (modeled estimate, per 100,000 live births)'],
            x = 'Country Name', y='2020',hue='Country Name')
plt.title('Maternal mortality ratio (modeled estimate, per 100,000 live births)')
plt.show()

# %%
sns.lineplot(data=african_countries[african_countries['Indicator Name'] == 'Lifetime risk of maternal death (%)'],
            x = 'Country Name', y='2020',hue='Country Name')
plt.title('Lifetime risk of maternal death (%)')
plt.show()

# %%
plt.style.use ('fivethirtyeight')
slices= [1047,1223,1063]
labels = ['Nigeria', 'South Sudan', 'Chad']
colors = ['#dda0dd', '#a0ddd2', '#b4a0dd']
explode = [0,0.1,0]


 #['#008fd5', '#e5ae37', '#6d984f']
plt.pie(slices, labels=labels, explode=explode, shadow=True, startangle=90, autopct= '%1.1f%%',colors=colors, wedgeprops={'edgecolor':'black'})

plt.title('Maternal mortality ratio (modeled estimate, per 100,000 live births)')
plt.tight_layout()
plt.show()

# %%
plt.style.use ('fivethirtyeight')
slices= [345,307,357]
labels = ['Nigeria', 'South Sudan', 'Chad']
colors = ['#dda0dd', '#a0ddd2', '#b4a0dd']
explode = [0,0,0.1]


 #['#008fd5', '#e5ae37', '#6d984f']
plt.pie(slices, labels=labels, explode=explode, shadow=True, startangle=90, autopct= '%1.1f%%',colors=colors, wedgeprops={'edgecolor':'black'})

plt.title('Mortality rate, adult, female (per 1,000 female adults)')
plt.tight_layout()
plt.show()
